# %%
import pynnp as pn
import numpy as np

import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ### select and smaple data set

# %%
pn.RuNNerAdaptorForVASP().read_runner("input.data").sample(2).write_runner("input.data.sel")

# %% [markdown]
# ### delete samples from data set

# %%
pn.RunnerAdaptor().read_runner("input.data").delete(range(0,749)).write_runner("input.data.del")

# %%
data = pn.RunnerAdaptor().read_runner("input.data")
data2 = pn.RunnerAdaptor().read_runner("input.data.0")

# %%
plt.plot(data.calculate_energy_errors(data2)*pn.HARTREE_TO_EV)

# %%
plt.plot(data.calculate_force_errors(data2, method='max')*pn.HARTREE_TO_EV)

# %%
# len(data.get_forces(range(0,2)))

# %%
data.range_of_energy
# Out:
# 0.002023713745360839

# %%
data.range_of_force*pn.HARTREE_TO_EV
# Out:
# 4.769505932209575
